// %% [markdown]
// # 11
//
// This is a text cell. Start editing!

// %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(19680801)
data = np.random.randn(2, 100)

fig, axs = plt.subplots(2, 2, figsize=(5, 5))
axs[0, 0].hist(data[0])
axs[1, 0].scatter(data[0], data[1])
axs[0, 1].plot(data[0], data[1])
axs[1, 1].hist2d(data[0], data[1])

plt.show()
// Out:
// <div style='width:600px'><?xml version="1.0" encoding="utf-8" standalone="no"?>
// <!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN"
//   "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd">
// <!-- Created with matplotlib (https://matplotlib.org/) -->
// <svg height="360pt" version="1.1" viewBox="0 0 360 360" width="360pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
//  <defs>
//   <style type="text/css">
// *{stroke-linecap:butt;stroke-linejoin:round;}
//   </style>
//  </defs>
//  <g id="figure_1">
//   <g id="patch_1">
//    <path d="M 0 360
// L 360 360
// L 360 0
// L 0 0
// z
// " style="fill:#ffffff;"/>
//   </g>
//   <g id="axes_1">
//    <g id="patch_2">
//     <path d="M 45 169.2
// L 171.818182 169.2
// L 171.818182 43.2
// L 45 43.2
// z
// " style="fill:#ffffff;"/>
//    </g>
//    <g id="patch_3">
//     <path clip-path="url(#p7ec9ad2a48)" d="M 50.764463 169.2
// L 62.293388 169.2
// L 62.293388 162.533333
// L 50.764463 162.533333
// z
// ...

// %%
case class Artist(artist: String = "Javad", genre: String, rank: Float = 10f)
val joe: Artist = new Artist("Joe Satriani", "Rock Blues", 4.3f)
val steve: Artist = new Artist("Steve Vai", "Rock", 4.5f)

println(joe)
println(steve)
joe
steve

val res = joe == steve
val res1 = if (joe == steve) true else new Artist(genre = "Metal")
// Out:
// Artist(Joe Satriani,Rock Blues,4.3)
// Artist(Steve Vai,Rock,4.5)
// [Ljava.lang.String;@6d268991

// %%
class Artist(name: String, age: Long) {
    print("hi", 3)
}

// new Artist("Javad", 35)

import java.time.LocalDate

class StockRate(symb: String, date: LocalDate, open: Double, close: Double, min: Double, max: Double) {
    override def toString() = symb + " " + date
}

val s = new StockRate("وتجارت", LocalDate.now(), 100.0, 110.0, 99.0, 120.1524)
s.toString
print(s)
// companion obejct
// object Artist {
//     def add (a1: Artist, a2: Artist): Unit = {
//        // print(a1.name + a2.name)
//     }
// }

"Javad Sabbagh".split(" ")

 val trades: Array[StockRate] = Array(s)

 object Hello {
     print("Mashdi mammad")

     def message = "Hi there!"
     val name = "Gholi"
 }

case object Test {
    override def toString = "Test object"
}
Test.toString
// Out:
// وتجارت 2020-04-20
// Test object
